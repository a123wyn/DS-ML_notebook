# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
info=pd.read_excel('./data/2.xlsx',sheet_name='企业信息')
info.head(5)
income=pd.read_excel('./data/2.xlsx',sheet_name='进项发票信息')
income.head(5)
outcome=pd.read_excel('./data/2.xlsx',sheet_name='销项发票信息')
outcome.head(5)
# Out:
#    企业代号      发票号码                开票日期  购方单位代号         金额        税额  \
# 0  E124  15212483 2017-09-01 11:58:43  D00585  83.935055  9.232856
# 1  E124  15212484 2017-09-01 11:59:20  D00585  90.090090  9.909910
# 2  E124  15212485 2017-09-01 11:59:51  D00585  90.090090  9.909910
# 3  E124  15212486 2017-09-01 12:00:45  D00585  69.736574  7.671023
# 4  E124   6089615 2017-09-05 10:58:38  D00108  72.621622  7.988378
#
#          价税合计  发票状态
# 0   93.167911  有效发票
# 1  100.000000  有效发票
# 2  100.000000  有效发票
# 3   77.407597  有效发票
# 4   80.610000  有效发票

# %%
income.dropna(axis=0)
outcome.dropna(axis=0)
# 废票率看销项发票信息，是该公司开的发票
for i in range(124,426):
    no='E'+str(i)
    info.loc[(info['企业代号']==no),'总票数']=pd.DataFrame(outcome.loc[outcome['企业代号']==no].count()).iloc[0,0]
    info.loc[(info['企业代号']==no),'废票数']=pd.DataFrame(outcome.loc[(outcome['发票状态']=='作废发票')&(outcome['企业代号']==no)].count()).iloc[0,0]
info['废票率']=info['废票数']/info['总票数']
info.head(5)
# Out:
#    企业代号       企业名称     总销售额(不含税)  发票状态     总票数    废票数       废票率
# 0  E124  个体经营E124   74178.036783  有效发票  1293.0  194.0  0.150039
# 1  E125  个体经营E125   94121.136449  有效发票  1595.0  215.0  0.134796
# 2  E126  个体经营E126   52069.109782  有效发票  1516.0  252.0  0.166227
# 3  E127  个体经营E127   65193.795453  有效发票  4026.0  122.0  0.030303
# 4  E128  个体经营E128   24239.015179  有效发票  1255.0   94.0  0.074900

# %%
# 删掉作废发票
income.drop(index=(income.loc[(income['发票状态']=='作废发票')].index),axis=0,inplace=True)
outcome.drop(index=(outcome.loc[(outcome['发票状态']=='作废发票')].index),axis=0,inplace=True)
# info=pd.merge(info,pd.DataFrame(outcome.groupby('企业代号')['金额'].sum()),how='inner',on='企业代号')
# info.head(5)

# %%
# info.rename(columns={'金额':'总销售额'},inplace=True)
# info.drop(index=(info.loc[(info['信誉评级']=='D')].index),axis=0,inplace=True)

# %%
# outcome['开票日期']=pd.to_datetime(outcome['开票日期'])
# outcome=outcome.set_index('企业代号')
#手动分割月份
# dic = {
#     "2016-10": "1610",
#     "2016-11": "1611",
#     "2016-12": "1612", 
    
#     "2017-01": "1701",
#     "2017-02": "1702",
#     "2017-03": "1703",
#     "2017-04": "1704",
#     "2017-05": "1705",
#     "2017-06": "1706",    
#     "2017-07": "1707",
#     "2017-08": "1708",
#     "2017-09": "1709",
#     "2017-10": "1710",
#     "2017-11": "1711",
#     "2017-12": "1712",   
    
#     "2018-01": "1813",
#     "2018-02": "18Q1",
#     "2018-03": "18Q1",
#     "2018-04": "18Q2",
#     "2018-05": "18Q2",
#     "2018-06": "18Q2",    
#     "2018-07": "18Q3",
#     "2018-08": "18Q3",
#     "2018-09": "18Q3",
#     "2018-10": "18Q4",
#     "2018-11": "18Q4",
#     "2018-12": "18Q4",   
    
#     "2019-01": "19Q1",
#     "2019-02": "19Q1",
#     "2019-03": "19Q1",
#     "2019-04": "19Q2",
#     "2019-05": "19Q2",
#     "2019-06": "19Q2", 
#     "2019-07": "19Q3",
#     "2019-08": "19Q3",
#     "2019-09": "19Q3",
#     "2019-10": "19Q4",
#     "2019-11": "19Q4",
#     "2019-12": "19Q4",
    
#     "2020-01": "20Q1",
#     "2020-02": "20Q1",
#     "2020-03": "20Q1",
# }
# outcome['季度']=outcome['年与月'].map(dic)

# %%
# outcome=pd.merge(outcome,pd.DataFrame(outcome.groupby([outcome['企业代号'],outcome['季度']])['金额'].sum()),on=['企业代号','季度'])
# outcome.rename(columns={'金额_y':'季度销售额'},inplace=True)

# %%
# 生成年份与月份
outcome['年与月']=outcome['开票日期'].apply(lambda x:x.strftime("%Y-%m-%d")).map(lambda x:x[:7])
outcome['年']=outcome['开票日期'].apply(lambda x:x.strftime("%Y-%m-%d")).map(lambda x:x[:4])
income['年与月']=income['开票日期'].apply(lambda x:x.strftime("%Y-%m-%d")).map(lambda x:x[:7])
income['年']=income['开票日期'].apply(lambda x:x.strftime("%Y-%m-%d")).map(lambda x:x[:4])
# income['季度']=income['年与月'].map(dic)
income.head(5)
# Out:
#    企业代号      发票号码                开票日期  销方单位代号        金额        税额     价税合计  \
# 0  E124  18891676 2017-09-01 00:00:00  C00014  0.033846  0.005754   0.0396
# 1  E124  18691267 2017-09-01 00:00:00  C00480  0.023010  0.000690   0.0237
# 2  E124  12995412 2017-09-01 00:00:00  C23675  0.022330  0.000670   0.0230
# 3  E124   6378193 2017-09-01 11:11:03  C00333  9.009009  0.990991  10.0000
# 4  E124   6378194 2017-09-01 11:12:01  C00333  9.009009  0.990991  10.0000
#
#    发票状态      年与月     年
# 0  有效发票  2017-09  2017
# 1  有效发票  2017-09  2017
# 2  有效发票  2017-09  2017
# 3  有效发票  2017-09  2017
# 4  有效发票  2017-09  2017

# %%
# 计算每个公司月份的销售额和进价额
outcome_q=pd.DataFrame(outcome.groupby([outcome['企业代号'],outcome['年与月']])['金额'].sum())
profit=pd.merge(outcome_q,pd.DataFrame(income.groupby([income['企业代号'],income['年与月']])['金额'].sum()),on=['企业代号','年与月'],how='outer')
profit=profit.fillna(0)
profit.rename(columns={'金额_x':'out_month','金额_y':'in_month'},inplace=True)
profit.head()
# Out:
#                 out_month     in_month
# 企业代号 年与月
# E124 2017-09  1459.075309  1596.102634
#      2017-10  1487.360603  1074.104273
#      2017-11  1802.381032  1451.259299
#      2017-12  3967.531443  2187.626520
#      2018-01  2135.661576  3718.859969

# %%
# # 计算每个公司季度的销售额和进价额
# outcome_q=pd.DataFrame(outcome.groupby([outcome['企业代号'],outcome['年与月']])['金额'].sum())
# profit=pd.merge(outcome_q,pd.DataFrame(income.groupby([income['企业代号'],income['年与月']])['金额'].sum()),on=['企业代号','年与月'],how='outer')
# profit=profit.fillna(0)
# profit.rename(columns={'金额_x':'out_month','金额_y':'in_month'},inplace=True)
# profit

# %%
# income=pd.merge(income,pd.DataFrame(income.groupby([income['企业代号'],income['季度']])['金额'].sum()),on=['企业代号','季度'])
# income.rename(columns={'金额_y':'季度进货额'},inplace=True)

# %%
# 计算每个公司季度的销售额和进价额
# outcome_q=pd.DataFrame(outcome.groupby([outcome['企业代号'],outcome['季度']])['金额'].sum())
# profit=pd.merge(outcome_q,pd.DataFrame(income.groupby([income['企业代号'],income['季度']])['金额'].sum()),how='outer')
# profit=profit.fillna(0)
# profit.rename(columns={'金额_x':'out','金额_y':'in'},inplace=True)
# profit

# %%
# 求每个月的利润及利润率
profit['profit']=profit['out_month']-profit['in_month']
profit['销售利润率']=profit['profit']/profit['out_month']
profit['成本费用利润率']=profit['profit']/profit['in_month']
profit.dropna(axis=0)
# Out:
#                 out_month     in_month       profit     销售利润率   成本费用利润率
# 企业代号 年与月
# E124 2017-09  1459.075309  1596.102634  -137.027325 -0.093914 -0.085851
#      2017-10  1487.360603  1074.104273   413.256330  0.277845  0.384745
#      2017-11  1802.381032  1451.259299   351.121733  0.194810  0.241943
#      2017-12  3967.531443  2187.626520  1779.904923  0.448618  0.813624
#      2018-01  2135.661576  3718.859969 -1583.198393 -0.741315 -0.425721
#      2018-02  4001.740392  3525.661187   476.079205  0.118968  0.135033
#      2018-03   372.374242   530.268685  -157.894443 -0.424021 -0.297763
#      2018-04   704.283553  1608.959496  -904.675943 -1.284534 -0.562274
#      2018-05  3276.916253  2225.610121  1051.306132  0.320822  0.472368
#      2018-06  2168.450463  3095.257765  -926.807302 -0.427405 -0.299428
#      2018-07  1362.772979  1967.100922  -604.327943 -0.443455 -0.307218
#      2018-08  2352.201535  2815.446950  -463.245415 -0.196941 -0.164537
#      2018-09  1699.332431  2300.965211  -601.632780 -0.354041 -0.261470
#      2018-10  3482.400964  3078.124388   404.276576  0.116091  0.131339
#      2018-11  1300.735111  2410.769832 -1110.034721 -0.853390 -0.460448
#      2018-12  3712.488947  3902.015350  -189.526403 -0.051051 -0.048571
#      2019-01  9656.036514  8915.230549   740.805965  0.076719  0.083094
#      2019-02  1700.886533   821.655366   879.231167  0.516925  1.070073
#      2019-03  1942.442075  2608.446493  -666.004418 -0.342870 -0.255326
#      2019-04  3707.106053  4018.479171  -311.373118 -0.083994 -0.077485
#      2019-05  3307.711060  4842.384641 -1534.673581 -0.463968 -0.316925
#      2019-06  5209.371956  4981.339160   228.032796  0.043774  0.045777
#      2019-07  4833.861903  5908.747751 -1074.885848 -0.222366 -0.181914
#      2019-08  5233.495723  5866.709855  -633.214132 -0.120993 -0.107933
#      2019-09  3301.418133  3101.427946   199.990187  0.060577  0.064483
# E125 2017-01  2607.811310   299.584155  2308.227155  0.885120  7.704770
#      2017-03   611.971150   308.386751   303.584399  0.496076  0.984428
#      2017-04   390.264916   221.450354   168.814562  0.432564  0.762313
#      2017-05   628.015995   573.982827    54.033168  0.086038  0.094137
#      2017-06  1246.816207   435.166149   811.650058  0.650978  1.865150
# ...                   ...          ...          ...       ...       ...
# E423 2018-04     0.000000     0.993657    -0.993657      -inf -1.000000
#      2018-05     0.000000     0.026415    -0.026415      -inf -1.000000
#      2018-07     0.000000     0.120485    -0.120485      -inf -1.000000
#      2018-09     0.000000     0.280172    -0.280172      -inf -1.000000
#      2018-10     0.000000     0.106058    -0.106058      -inf -1.000000
#      2019-04     0.000000     0.172046    -0.172046      -inf -1.000000
#      2019-06     0.000000     1.260824    -1.260824      -inf -1.000000
# E424 2018-04     0.000000     2.498611    -2.498611      -inf -1.000000
#      2018-09     0.000000     0.887481    -0.887481      -inf -1.000000
#      2019-03     0.000000     0.125862    -0.125862      -inf -1.000000
#      2019-04     0.000000     0.560505    -0.560505      -inf -1.000000
#      2019-06     0.000000     1.743491    -1.743491      -inf -1.000000
# E425 2018-02     0.000000     0.128155    -0.128155      -inf -1.000000
#      2018-05     0.000000     0.293415    -0.293415      -inf -1.000000
#      2018-06     0.000000     0.344836    -0.344836      -inf -1.000000
#      2018-07     0.000000     0.213060    -0.213060      -inf -1.000000
#      2018-08     0.000000     0.308867    -0.308867      -inf -1.000000
#      2018-12     0.000000     0.120162    -0.120162      -inf -1.000000
#      2019-01     0.000000     0.299375    -0.299375      -inf -1.000000
#      2019-02     0.000000     0.019504    -0.019504      -inf -1.000000
#      2019-03     0.000000     0.218237    -0.218237      -inf -1.000000
#      2019-04     0.000000     0.099404    -0.099404      -inf -1.000000
#      2019-05     0.000000     0.104162    -0.104162      -inf -1.000000
#      2019-07     0.000000     0.609675    -0.609675      -inf -1.000000
#      2019-08     0.000000     0.149063    -0.149063      -inf -1.000000
#      2019-09     0.000000     0.135431    -0.135431      -inf -1.000000
#      2019-10     0.000000     0.423879    -0.423879      -inf -1.000000
#      2019-11     0.000000     0.427170    -0.427170      -inf -1.000000
#      2019-12     0.000000     0.106574    -0.106574      -inf -1.000000
#      2020-01     0.000000     0.036081    -0.036081      -inf -1.000000
#
# [9726 rows x 5 columns]

# %%
# 最大利润率超过100%即为暴利，于是我们将所有正无穷大的数设成1，负无穷为-1
profit['销售利润率'].replace(-np.Inf, -1,inplace=True)
profit['销售利润率'].replace(np.Inf, 1,inplace=True)
profit=profit.reset_index()
info=pd.merge(info,pd.DataFrame(profit.groupby('企业代号')['销售利润率'].mean()),on='企业代号',how='left')

profit['成本费用利润率'].replace(-np.Inf, -1,inplace=True)
profit['成本费用利润率'].replace(np.Inf, 1,inplace=True)
info=pd.merge(info,pd.DataFrame(profit.groupby('企业代号')['成本费用利润率'].mean()),on='企业代号',how='left')
info
# Out:
#      企业代号               企业名称     总销售额(不含税)  发票状态      总票数    废票数       废票率  \
# 0    E124          个体经营E124   74178.036783  有效发票   1293.0  194.0  0.150039
# 1    E125          个体经营E125   94121.136449  有效发票   1595.0  215.0  0.134796
# 2    E126          个体经营E126   52069.109782  有效发票   1516.0  252.0  0.166227
# 3    E127          个体经营E127   65193.795453  有效发票   4026.0  122.0  0.030303
# 4    E128          个体经营E128   24239.015179  有效发票   1255.0   94.0  0.074900
# 5    E129          个体经营E129   32480.603262  有效发票   5817.0  636.0  0.109335
# 6    E130          个体经营E130   11003.667288  有效发票   1382.0   61.0  0.044139
# 7    E131          个体经营E131   20908.403179  有效发票   3336.0  239.0  0.071643
# 8    E132          个体经营E132   20335.826185  有效发票   1798.0  139.0  0.077308
# 9    E133          个体经营E133   11365.501438  有效发票    170.0   30.0  0.176471
# 10   E134        ***工程咨询有限公司  12281.546998  有效发票   3070.0  235.0  0.076547
# 11   E135        ***建设工程有限公司  13553.755852  有效发票    413.0   46.0  0.111380
# 12   E136        ***机械有限责任公司  11665.218536  有效发票   1355.0   71.0  0.052399
# 13   E137        ***建设工程有限公司  14326.437292  有效发票    254.0   23.0  0.090551
# 14   E138          个体经营E138   10783.174103  有效发票   1492.0   53.0  0.035523
# 15   E139          个体经营E139   18771.352739  有效发票  12822.0  613.0  0.047808
# 16   E140        ***建筑工程有限公司  18242.903305  有效发票    845.0  119.0  0.140828
# 17   E141          ***食品有限公司  15937.496820  有效发票   4740.0  282.0  0.059494
# 18   E142          ***运业有限公司   9726.767964  有效发票   1476.0  108.0  0.073171
# 19   E143        ***电子科技有限公司   9043.986444  有效发票   1150.0   51.0  0.044348
# 20   E144          ***劳务有限公司  10416.830574  有效发票   1360.0  115.0  0.084559
# 21   E145          ***工贸有限公司  11756.972006  有效发票   4271.0  426.0  0.099742
# 22   E146      ***基础建设工程有限公司  13111.060843  有效发票   1612.0  196.0  0.121588
# 23   E147      ***装饰工程有限责任公司  18766.978307  有效发票   2371.0   57.0  0.024040
# 24   E148          ***商贸有限公司   8056.817317  有效发票    281.0   11.0  0.039146
# 25   E149        ***建筑劳务有限公司  10124.060626  有效发票   1226.0   79.0  0.064437
# 26   E150        ***建设工程有限公司  11425.837514  有效发票    464.0   54.0  0.116379
# 27   E151        ***路桥工程有限公司  10242.115295  有效发票    148.0    8.0  0.054054
# 28   E152        ***运贸有限责任公司  11961.172799  有效发票   1525.0   37.0  0.024262
# 29   E153          个体经营E153   24102.376776  有效发票    355.0   75.0  0.211268
# ..    ...                ...           ...   ...      ...    ...       ...
# 272  E396        ***文化传播有限公司     61.813035  有效发票     70.0    5.0  0.071429
# 273  E397          ***大闸蟹经营部     65.021496  有效发票    183.0   51.0  0.278689
# 274  E398      ***医疗管理咨询有限公司     61.886738  有效发票     89.0    0.0  0.000000
# 275  E399        ***装饰工程有限公司     44.216001  有效发票     19.0    4.0  0.210526
# 276  E400         ***办公用品经营部     81.564797  有效发票    134.0   12.0  0.089552
# 277  E401        ***遮阳技术发展中心     31.403071  有效发票     77.0   38.0  0.493506
# 278  E402          ***商贸有限公司     47.038958  有效发票     25.0    3.0  0.120000
# 279  E403          ***机械有限公司    119.754835  有效发票     70.0    9.0  0.128571
# 280  E404          个体经营E404      83.029222  有效发票     21.0    6.0  0.285714
# 281  E405      ***职业技能服务有限公司     59.143300  有效发票     45.0   20.0  0.444444
# 282  E406       ***招投标代理有限公司     83.176644  有效发票     31.0    7.0  0.225806
# 283  E407        ***装饰工程有限公司    184.894465  有效发票     44.0   13.0  0.295455
# 284  E408      ***空调制冷有限责任公司     52.214294  有效发票     32.0    6.0  0.187500
# 285  E409          ***塑胶有限公司     21.643045  有效发票    101.0   11.0  0.108911
# 286  E410        ***网络科技有限公司     40.696583  有效发票     66.0    1.0  0.015152
# 287  E411        ***机电设备有限公司     26.030524  有效发票     97.0   30.0  0.309278
# 288  E412        ***汽车贸易有限公司     32.055278  有效发票    149.0   12.0  0.080537
# 289  E413       ***石材工艺品有限公司     28.697887  有效发票     40.0    7.0  0.175000
# 290  E414  ***物流有限责任公司***分公司     37.708737  有效发票     14.0    3.0  0.214286
# 291  E415         ***广告设计服务部      8.532875  有效发票    208.0    0.0  0.000000
# 292  E416          ***科技有限公司     20.941441  有效发票     25.0    2.0  0.080000
# 293  E417      ***园林景观工程有限公司     16.166992  有效发票      6.0    0.0  0.000000
# 294  E418        ***营销策划有限公司     42.583054  有效发票     23.0    3.0  0.130435
# 295  E419          ***科技有限公司      5.207547  有效发票      4.0    0.0  0.000000
# 296  E420             ***康药房      7.163027  有效发票    126.0   12.0  0.095238
# 297  E421        ***保温材料有限公司     24.570076  有效发票     29.0    1.0  0.034483
# 298  E422             ***童装店      2.701831  有效发票     30.0    3.0  0.100000
# 299  E423        ***通风设备有限公司      7.278640  有效发票      7.0    1.0  0.142857
# 300  E424          ***贸易有限公司      7.689642  有效发票     43.0    6.0  0.139535
# 301  E425          ***商贸有限公司      8.512621  有效发票     18.0    8.0  0.444444
#
#             销售利润率      成本费用利润率
# 0   -1.571643e-01    -0.016416
# 1   -4.529000e-02     0.304449
# 2    7.330121e-01     4.629326
# 3    9.928676e-01  2191.648161
# 4    5.081518e-01    47.311271
# 5    7.194015e-01     7.629711
# 6   -4.873833e+00    83.489936
# 7    5.109054e-01     1.749276
# 8    3.483331e-01  3347.769983
# 9   -2.335389e-01   394.632719
# 10   9.770141e-01   239.325155
# 11   7.641818e-01   251.197256
# 12  -3.119555e-01   330.584968
# 13  -1.181734e+00     4.406072
# 14   7.805225e-01   198.681819
# 15   9.930270e-01   836.059015
# 16   1.805247e+12   244.354560
# 17   7.223312e-01     5.421800
# 18   5.122425e-01     1.341973
# 19  -3.415770e+00     3.089388
# 20   1.203018e+13    51.459307
# 21   1.034721e-02     0.219493
# 22  -2.038954e-01    37.759817
# 23  -4.259720e-01     0.852543
# 24  -9.546568e-02  8315.811905
# 25  -9.489426e-01  1951.828210
# 26   9.664725e-03     2.845095
# 27   1.825546e-02   133.420676
# 28   9.514463e-01    26.003523
# 29   7.905031e-01  6249.930060
# ..            ...          ...
# 272 -5.352895e-01     0.682783
# 273  1.299703e-02    35.269586
# 274 -1.141620e-01     9.261968
# 275 -4.642006e-01    17.031185
# 276  4.408496e-01    17.302229
# 277 -4.915873e-01     4.387394
# 278 -5.715001e-02     0.269740
# 279  8.555297e-01    44.298526
# 280 -5.272638e-01     0.863058
# 281  1.201820e-01     0.653779
# 282 -2.710972e-02     7.933941
# 283 -1.466572e-01     8.059136
# 284  1.225353e-01    16.805084
# 285  4.573524e-01     9.599281
# 286  7.153343e-01    19.711299
# 287  5.234751e-02     2.594000
# 288  4.042604e-01     3.595368
# 289 -2.448489e-01    18.678633
# 290  2.668355e-01     1.493633
# 291  8.763793e-01     0.887306
# 292  2.909055e-02     0.041187
# 293 -7.593473e-01     1.310778
# 294 -1.439165e-01    15.102560
# 295 -4.659329e+00    -0.996497
# 296 -5.393082e+01    -0.915866
# 297 -4.117216e-01     1.879647
# 298  6.614054e-01     0.967029
# 299 -2.941176e-01    -0.294118
# 300 -2.840203e+01    -0.221047
# 301 -7.426355e-01     0.544303
#
# [302 rows x 9 columns]

# %%
profit.to_excel('利润表.xlsx')

# %%
# 用户销售的总金额
client_sum=pd.DataFrame(outcome.groupby([outcome['企业代号'],outcome['购方单位代号']])['金额'].sum()).sort_values(by=['企业代号','金额'],ascending=[True,True])
client_sum.rename(columns={'金额':'总金额'},inplace=True)
client_sum=client_sum.fillna(0)
client_sum
# 用户销售的标准差
client_std=pd.DataFrame(outcome.groupby([outcome['企业代号'],outcome['购方单位代号']])['金额'].std()).sort_values(by=['企业代号','金额'],ascending=[True,True])
client_std.rename(columns={'金额':'标准差'},inplace=True)
client_std=client_std.fillna(0)
client_std
# 用户销售的均值
client_mean=pd.DataFrame(outcome.groupby([outcome['企业代号'],outcome['购方单位代号']])['金额'].mean()).sort_values(by=['企业代号','金额'],ascending=[True,False])
client_mean.rename(columns={'金额':'均值'},inplace=True)
client_mean=client_mean.fillna(0)
client_mean
# Out:
#                     均值
# 企业代号 购方单位代号
# E124 D00135  92.542100
#      D00215  91.203535
#      D00524  90.292967
#      D00027  90.090090
#      D00385  87.036555
#      D00013  86.230779
#      D00661  86.029078
#      D00023  81.511996
#      D00387  80.288695
#      D00666  79.798312
#      D00229  78.330348
#      D00768  77.053513
#      D00011  76.203604
#      D00504  73.709774
#      D00648  73.571256
#      D00547  73.465690
#      D00164  73.325304
#      D00362  72.443052
#      D00108  71.793061
#      D00528  68.561750
#      D00615  68.083289
#      D00394  67.905630
#      D00201  67.434746
#      D00585  67.368824
#      D00674  67.074955
#      D00672  65.191632
#      D00140  64.152750
#      D00022  63.732433
#      D00228  62.670974
#      D00020  61.222531
# ...                ...
# E422 D08984   0.032000
#      D15075   0.025534
#      D17015   0.014466
#      D29212   0.008573
# E423 D14463   1.920873
#      D17060   0.873787
#      D14467   0.844660
# E424 D17122   0.930000
#      D24625   0.237800
#      D21491   0.053660
#      D12066   0.040388
#      D28986   0.035600
#      D21024   0.031600
#      D10583   0.029709
#      D13307   0.025825
#      D05283   0.021200
#      D20648   0.021165
#      D21555   0.020194
#      D01357   0.019800
#      D05398   0.018058
#      D05180   0.017800
#      D05467   0.016117
#      D02483   0.015800
#      D05070   0.015800
#      D13382   0.015800
#      D09482   0.015340
#      D20605   0.015340
#      D25568   0.014369
# E425 D21446   0.891909
#      D02126   0.485437
#
# [50929 rows x 1 columns]

# %%
# 变异系数越大说明越不稳定
pd.DataFrame(client_std['标准差']/client_mean['均值'])
client=pd.merge(client_sum,pd.DataFrame(client_std['标准差']/client_mean['均值']),on=['企业代号','购方单位代号'],how='left')
client.rename(columns={0:'变异系数'},inplace=True)
client=client.reset_index()
client
# Out:
#        企业代号  购方单位代号         总金额      变异系数
# 0      E124  D00072    0.291086  0.833653
# 1      E124  D00124    1.310680  0.000000
# 2      E124  D00025    1.673400  0.000000
# 3      E124  D00024    8.290000  0.000000
# 4      E124  D00031   15.769613  0.000000
# 5      E124  D00117   28.514297  0.000000
# 6      E124  D00093   29.486036  0.000000
# 7      E124  D00012   30.465766  0.000000
# 8      E124  D18704   34.285714  0.000000
# 9      E124  D00743   47.620288  0.304176
# 10     E124  D00027   90.090090  0.000000
# 11     E124  D00106  110.810811  1.131371
# 12     E124  D00022  127.464865  0.584873
# 13     E124  D00116  184.534412  0.811475
# 14     E124  D00018  222.401891  0.629299
# 15     E124  D00134  322.916745  0.464368
# 16     E124  D00228  376.025847  0.607298
# 17     E124  D00215  456.017676  0.032603
# 18     E124  D00023  489.071978  0.307452
# 19     E124  D00028  494.845372  0.004613
# 20     E124  D00608  506.405535  0.344718
# 21     E124  D00547  514.259829  0.280142
# 22     E124  D00661  516.174467  0.200851
# 23     E124  D00013  517.384677  0.156585
# 24     E124  D00229  548.312439  0.259162
# 25     E124  D00201  606.912717  0.360764
# 26     E124  D00020  612.225306  0.532109
# 27     E124  D00518  613.474162  0.616517
# 28     E124  D00768  616.428107  0.264723
# 29     E124  D00648  662.141303  0.463671
# ...     ...     ...         ...       ...
# 50899  E422  D26925    0.233009  0.353558
# 50900  E422  D11109    0.252427  0.000000
# 50901  E422  D14382    0.275146  0.981067
# 50902  E422  D14026    0.810680  0.000000
# 50903  E423  D14467    1.689320  0.016256
# 50904  E423  D17060    1.747573  0.314269
# 50905  E423  D14463    3.841747  1.001779
# 50906  E424  D25568    0.014369  0.000000
# 50907  E424  D09482    0.015340  0.000000
# 50908  E424  D02483    0.015800  0.000000
# 50909  E424  D05070    0.015800  0.000000
# 50910  E424  D13382    0.015800  0.000000
# 50911  E424  D05467    0.016117  0.000000
# 50912  E424  D05180    0.017800  0.000000
# 50913  E424  D05398    0.018058  0.000000
# 50914  E424  D01357    0.019800  0.000000
# 50915  E424  D21555    0.020194  0.000000
# 50916  E424  D20648    0.021165  0.000000
# 50917  E424  D05283    0.021200  0.000000
# 50918  E424  D13307    0.025825  0.000000
# 50919  E424  D10583    0.029709  0.000000
# 50920  E424  D20605    0.030680  0.000000
# 50921  E424  D21024    0.031600  0.000000
# 50922  E424  D28986    0.035600  0.000000
# 50923  E424  D12066    0.040388  0.000000
# 50924  E424  D24625    0.237800  0.000000
# 50925  E424  D21491    0.536597  1.773813
# 50926  E424  D17122    6.510000  0.000000
# 50927  E425  D02126    0.485437  0.000000
# 50928  E425  D21446    8.027184  0.161822
#
# [50929 rows x 4 columns]

# %%
# 需求不稳定性
for i in range(124,426):
    no='E'+str(i)
    a=client.loc[client['企业代号']==no]
    a['百分比']=a['总金额']/a['总金额'].sum()
#     a['百分比'] = (a['总金额'] - a['总金额'].min())/(a['总金额'].max() - a['总金额'].min())
    info.loc[(info['企业代号']==no),'需求不稳定性']=a['百分比'].mul(a['变异系数']).sum()
#     info.loc[(info['企业代号']==no),'需求因子']=a['总金额'].mul(a['变异系数']).sum()
a
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#        企业代号  购方单位代号       总金额      变异系数       百分比
# 50927  E425  D02126  0.485437  0.000000  0.057026
# 50928  E425  D21446  8.027184  0.161822  0.942974

# %%
info
# Out:
#      企业代号               企业名称     总销售额(不含税)  发票状态      总票数    废票数       废票率  \
# 0    E124          个体经营E124   74178.036783  有效发票   1293.0  194.0  0.150039
# 1    E125          个体经营E125   94121.136449  有效发票   1595.0  215.0  0.134796
# 2    E126          个体经营E126   52069.109782  有效发票   1516.0  252.0  0.166227
# 3    E127          个体经营E127   65193.795453  有效发票   4026.0  122.0  0.030303
# 4    E128          个体经营E128   24239.015179  有效发票   1255.0   94.0  0.074900
# 5    E129          个体经营E129   32480.603262  有效发票   5817.0  636.0  0.109335
# 6    E130          个体经营E130   11003.667288  有效发票   1382.0   61.0  0.044139
# 7    E131          个体经营E131   20908.403179  有效发票   3336.0  239.0  0.071643
# 8    E132          个体经营E132   20335.826185  有效发票   1798.0  139.0  0.077308
# 9    E133          个体经营E133   11365.501438  有效发票    170.0   30.0  0.176471
# 10   E134        ***工程咨询有限公司  12281.546998  有效发票   3070.0  235.0  0.076547
# 11   E135        ***建设工程有限公司  13553.755852  有效发票    413.0   46.0  0.111380
# 12   E136        ***机械有限责任公司  11665.218536  有效发票   1355.0   71.0  0.052399
# 13   E137        ***建设工程有限公司  14326.437292  有效发票    254.0   23.0  0.090551
# 14   E138          个体经营E138   10783.174103  有效发票   1492.0   53.0  0.035523
# 15   E139          个体经营E139   18771.352739  有效发票  12822.0  613.0  0.047808
# 16   E140        ***建筑工程有限公司  18242.903305  有效发票    845.0  119.0  0.140828
# 17   E141          ***食品有限公司  15937.496820  有效发票   4740.0  282.0  0.059494
# 18   E142          ***运业有限公司   9726.767964  有效发票   1476.0  108.0  0.073171
# 19   E143        ***电子科技有限公司   9043.986444  有效发票   1150.0   51.0  0.044348
# 20   E144          ***劳务有限公司  10416.830574  有效发票   1360.0  115.0  0.084559
# 21   E145          ***工贸有限公司  11756.972006  有效发票   4271.0  426.0  0.099742
# 22   E146      ***基础建设工程有限公司  13111.060843  有效发票   1612.0  196.0  0.121588
# 23   E147      ***装饰工程有限责任公司  18766.978307  有效发票   2371.0   57.0  0.024040
# 24   E148          ***商贸有限公司   8056.817317  有效发票    281.0   11.0  0.039146
# 25   E149        ***建筑劳务有限公司  10124.060626  有效发票   1226.0   79.0  0.064437
# 26   E150        ***建设工程有限公司  11425.837514  有效发票    464.0   54.0  0.116379
# 27   E151        ***路桥工程有限公司  10242.115295  有效发票    148.0    8.0  0.054054
# 28   E152        ***运贸有限责任公司  11961.172799  有效发票   1525.0   37.0  0.024262
# 29   E153          个体经营E153   24102.376776  有效发票    355.0   75.0  0.211268
# ..    ...                ...           ...   ...      ...    ...       ...
# 272  E396        ***文化传播有限公司     61.813035  有效发票     70.0    5.0  0.071429
# 273  E397          ***大闸蟹经营部     65.021496  有效发票    183.0   51.0  0.278689
# 274  E398      ***医疗管理咨询有限公司     61.886738  有效发票     89.0    0.0  0.000000
# 275  E399        ***装饰工程有限公司     44.216001  有效发票     19.0    4.0  0.210526
# 276  E400         ***办公用品经营部     81.564797  有效发票    134.0   12.0  0.089552
# 277  E401        ***遮阳技术发展中心     31.403071  有效发票     77.0   38.0  0.493506
# 278  E402          ***商贸有限公司     47.038958  有效发票     25.0    3.0  0.120000
# 279  E403          ***机械有限公司    119.754835  有效发票     70.0    9.0  0.128571
# 280  E404          个体经营E404      83.029222  有效发票     21.0    6.0  0.285714
# 281  E405      ***职业技能服务有限公司     59.143300  有效发票     45.0   20.0  0.444444
# 282  E406       ***招投标代理有限公司     83.176644  有效发票     31.0    7.0  0.225806
# 283  E407        ***装饰工程有限公司    184.894465  有效发票     44.0   13.0  0.295455
# 284  E408      ***空调制冷有限责任公司     52.214294  有效发票     32.0    6.0  0.187500
# 285  E409          ***塑胶有限公司     21.643045  有效发票    101.0   11.0  0.108911
# 286  E410        ***网络科技有限公司     40.696583  有效发票     66.0    1.0  0.015152
# 287  E411        ***机电设备有限公司     26.030524  有效发票     97.0   30.0  0.309278
# 288  E412        ***汽车贸易有限公司     32.055278  有效发票    149.0   12.0  0.080537
# 289  E413       ***石材工艺品有限公司     28.697887  有效发票     40.0    7.0  0.175000
# 290  E414  ***物流有限责任公司***分公司     37.708737  有效发票     14.0    3.0  0.214286
# 291  E415         ***广告设计服务部      8.532875  有效发票    208.0    0.0  0.000000
# 292  E416          ***科技有限公司     20.941441  有效发票     25.0    2.0  0.080000
# 293  E417      ***园林景观工程有限公司     16.166992  有效发票      6.0    0.0  0.000000
# 294  E418        ***营销策划有限公司     42.583054  有效发票     23.0    3.0  0.130435
# 295  E419          ***科技有限公司      5.207547  有效发票      4.0    0.0  0.000000
# 296  E420             ***康药房      7.163027  有效发票    126.0   12.0  0.095238
# 297  E421        ***保温材料有限公司     24.570076  有效发票     29.0    1.0  0.034483
# 298  E422             ***童装店      2.701831  有效发票     30.0    3.0  0.100000
# 299  E423        ***通风设备有限公司      7.278640  有效发票      7.0    1.0  0.142857
# 300  E424          ***贸易有限公司      7.689642  有效发票     43.0    6.0  0.139535
# 301  E425          ***商贸有限公司      8.512621  有效发票     18.0    8.0  0.444444
#
#             销售利润率      成本费用利润率    需求不稳定性
# 0   -1.571643e-01    -0.016416  0.494843
# 1   -4.529000e-02     0.304449  0.447909
# 2    7.330121e-01     4.629326  0.665965
# 3    9.928676e-01  2191.648161  0.922608
# 4    5.081518e-01    47.311271  1.357651
# 5    7.194015e-01     7.629711  0.403662
# 6   -4.873833e+00    83.489936  0.135512
# 7    5.109054e-01     1.749276  0.970455
# 8    3.483331e-01  3347.769983  0.479252
# 9   -2.335389e-01   394.632719  0.338326
# 10   9.770141e-01   239.325155  0.294689
# 11   7.641818e-01   251.197256  0.702755
# 12  -3.119555e-01   330.584968  0.129800
# 13  -1.181734e+00     4.406072  0.453929
# 14   7.805225e-01   198.681819  0.230676
# 15   9.930270e-01   836.059015  0.294745
# 16   1.805247e+12   244.354560  1.028702
# 17   7.223312e-01     5.421800  0.533301
# 18   5.122425e-01     1.341973  0.349843
# 19  -3.415770e+00     3.089388  0.989415
# 20   1.203018e+13    51.459307  0.272535
# 21   1.034721e-02     0.219493  0.590233
# 22  -2.038954e-01    37.759817  0.305600
# 23  -4.259720e-01     0.852543  0.237639
# 24  -9.546568e-02  8315.811905  0.509964
# 25  -9.489426e-01  1951.828210  0.216477
# 26   9.664725e-03     2.845095  0.619765
# 27   1.825546e-02   133.420676  0.310630
# 28   9.514463e-01    26.003523  0.183511
# 29   7.905031e-01  6249.930060  0.217440
# ..            ...          ...       ...
# 272 -5.352895e-01     0.682783  1.320822
# 273  1.299703e-02    35.269586  0.256917
# 274 -1.141620e-01     9.261968  0.063435
# 275 -4.642006e-01    17.031185  0.416782
# 276  4.408496e-01    17.302229  0.251139
# 277 -4.915873e-01     4.387394  0.182390
# 278 -5.715001e-02     0.269740  1.055649
# 279  8.555297e-01    44.298526  0.517919
# 280 -5.272638e-01     0.863058  0.349294
# 281  1.201820e-01     0.653779  0.250112
# 282 -2.710972e-02     7.933941  0.473309
# 283 -1.466572e-01     8.059136  0.678507
# 284  1.225353e-01    16.805084  0.678631
# 285  4.573524e-01     9.599281  0.419798
# 286  7.153343e-01    19.711299  0.363997
# 287  5.234751e-02     2.594000  0.360257
# 288  4.042604e-01     3.595368  0.318526
# 289 -2.448489e-01    18.678633  0.068843
# 290  2.668355e-01     1.493633  0.311932
# 291  8.763793e-01     0.887306  0.103753
# 292  2.909055e-02     0.041187  0.016060
# 293 -7.593473e-01     1.310778  0.141793
# 294 -1.439165e-01    15.102560  0.301167
# 295 -4.659329e+00    -0.996497  0.251022
# 296 -5.393082e+01    -0.915866  0.229492
# 297 -4.117216e-01     1.879647  0.112779
# 298  6.614054e-01     0.967029  0.148339
# 299 -2.941176e-01    -0.294118  0.607978
# 300 -2.840203e+01    -0.221047  0.123780
# 301 -7.426355e-01     0.544303  0.152594
#
# [302 rows x 10 columns]

# %%
# 原材料购买总金额
product_sum=pd.DataFrame(income.groupby([income['企业代号'],income['销方单位代号']])['金额'].sum()).sort_values(by=['企业代号','金额'],ascending=[True,False])
product_sum.rename(columns={'金额':'总金额'},inplace=True)
product_sum
# 原材料购买标准差
product_std=pd.DataFrame(income.groupby([income['企业代号'],income['销方单位代号']])['金额'].std()).sort_values(by=['企业代号','金额'],ascending=[True,True])
product_std.rename(columns={'金额':'标准差'},inplace=True)
product_std=product_std.fillna(0)
product_std
# 原材料购买的均值
product_mean=pd.DataFrame(income.groupby([income['企业代号'],income['销方单位代号']])['金额'].mean()).sort_values(by=['企业代号','金额'],ascending=[True,False])
product_mean.rename(columns={'金额':'均值'},inplace=True)
product_mean=product_mean.fillna(0)
product_mean
# Out:
#                      均值
# 企业代号 销方单位代号
# E124 C01240  236.811890
#      C00876   97.087379
#      C00070   86.990400
#      C01063   80.624465
#      C00859   67.558070
#      C00275   63.130406
#      C01006   62.160194
#      C00402   60.519026
#      C00027   54.975728
#      C00133   48.580097
#      C00236   48.543689
#      C00105   43.703884
#      C01188   40.188621
#      C00109   38.834951
#      C00177   38.244661
#      C00919   37.472686
#      C00860   36.398018
#      C00875   35.101942
#      C01216   33.965517
#      C01219   33.233647
#      C00264   31.773646
#      C00813   31.546926
#      C00716   31.456311
#      C00433   31.084884
#      C01346   30.559575
#      C00156   30.349456
#      C00663   28.204719
#      C00887   27.642048
#      C01337   26.924108
#      C01416   25.929572
# ...                 ...
# E424 C07715    0.026415
#      C12006    0.013365
#      C13842    0.007747
# E425 C16244    0.923077
#      C15374    0.471698
#      C16280    0.256311
#      C12064    0.253448
#      C02766    0.200000
#      C05650    0.189569
#      C12720    0.137845
#      C15880    0.122330
#      C15699    0.110000
#      C23112    0.086113
#      C06845    0.072453
#      C14180    0.060133
#      C05583    0.034219
#      C17430    0.031780
#      C12650    0.030388
#      C02374    0.028387
#      C06996    0.028238
#      C06557    0.025641
#      C15032    0.023011
#      C12709    0.022264
#      C13932    0.021698
#      C11365    0.019491
#      C01937    0.016192
#      C07715    0.014503
#      C12006    0.011256
#      C11315    0.008854
#      C17753    0.007085
#
# [74708 rows x 1 columns]

# %%
# 变异系数越大说明越不稳定
pd.DataFrame(product_std['标准差']/product_mean['均值'])
product=pd.merge(product_sum,pd.DataFrame(product_std['标准差']/product_mean['均值']),on=['企业代号','销方单位代号'],how='left')
product.rename(columns={0:'变异系数'},inplace=True)
product=product.reset_index()
product
# Out:
#        企业代号  销方单位代号           总金额      变异系数
# 0      E124  C01229  12457.414008  1.158245
# 1      E124  C01173   2953.283321  1.370006
# 2      E124  C00798   2419.590669  1.687806
# 3      E124  C00940   2339.362357  2.731271
# 4      E124  C00893   2061.590461  0.758201
# 5      E124  C01239   1678.362831  0.793883
# 6      E124  C01095   1468.249327  0.228345
# 7      E124  C01172   1446.185158  0.366130
# 8      E124  C00717   1292.078653  0.401833
# 9      E124  C01007   1157.768827  1.258785
# 10     E124  C00935   1126.506802  1.011621
# 11     E124  C00367   1051.077530  0.930432
# 12     E124  C01231   1045.731942  0.905077
# 13     E124  C00950   1010.768326  0.152825
# 14     E124  C00887    967.471682  0.980015
# 15     E124  C01240    947.247561  0.934458
# 16     E124  C00754    882.361789  1.235597
# 17     E124  C00678    859.820031  0.883278
# 18     E124  C01202    842.101389  0.931057
# 19     E124  C00332    773.004539  1.004967
# 20     E124  C00939    772.328403  1.378195
# 21     E124  C00941    760.519806  0.923852
# 22     E124  C01189    700.643838  0.833231
# 23     E124  C00860    655.164318  0.910006
# 24     E124  C00720    616.180167  0.589836
# 25     E124  C00712    613.703321  2.999019
# 26     E124  C00911    582.523812  0.380274
# 27     E124  C01287    552.389726  1.035848
# 28     E124  C00859    540.464561  0.514712
# 29     E124  C01226    527.460752  1.146639
# ...     ...     ...           ...       ...
# 74678  E424  C12006      0.026730  0.730121
# 74679  E424  C07715      0.026415  0.000000
# 74680  E424  C13842      0.007747  0.000000
# 74681  E425  C16244      0.923077  0.000000
# 74682  E425  C01937      0.793406  1.666467
# 74683  E425  C23112      0.516681  0.546948
# 74684  E425  C16280      0.512622  0.514259
# 74685  E425  C15880      0.489320  0.054983
# 74686  E425  C15374      0.471698  0.000000
# 74687  E425  C12064      0.253448  0.000000
# 74688  E425  C02766      0.200000  0.000000
# 74689  E425  C05650      0.189569  0.000000
# 74690  E425  C14180      0.180400  0.119054
# 74691  E425  C12006      0.146323  1.779251
# 74692  E425  C12720      0.137845  0.000000
# 74693  E425  C15699      0.110000  0.000000
# 74694  E425  C05583      0.102656  0.212593
# 74695  E425  C17430      0.095340  0.208505
# 74696  E425  C12650      0.091165  0.846809
# 74697  E425  C02374      0.085162  0.159698
# 74698  E425  C11365      0.077962  0.159428
# 74699  E425  C06845      0.072453  0.000000
# 74700  E425  C15032      0.069032  0.592739
# 74701  E425  C06996      0.056476  0.065657
# 74702  E425  C07715      0.043509  2.513425
# 74703  E425  C06557      0.025641  0.000000
# 74704  E425  C12709      0.022264  0.000000
# 74705  E425  C13932      0.021698  0.000000
# 74706  E425  C11315      0.017708  0.210519
# 74707  E425  C17753      0.014170  0.402208
#
# [74708 rows x 4 columns]

# %%
# 供给不稳定性
for i in range(124,426):
    no='E'+str(i)
    a=product.loc[product['企业代号']==no]
    a['百分比']=a['总金额']/a['总金额'].sum()
#     a['百分比'] = (a['总金额'] - a['总金额'].min())/(a['总金额'].max() - a['总金额'].min())
    info.loc[(info['企业代号']==no),'供给不稳定性']=a['百分比'].mul(a['变异系数']).sum()
#     info.loc[(info['企业代号']==no),'需求因子']=a['总金额'].mul(a['变异系数']).sum()
a
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#        企业代号  销方单位代号       总金额      变异系数       百分比
# 74681  E425  C16244  0.923077  0.000000  0.161388
# 74682  E425  C01937  0.793406  1.666467  0.138716
# 74683  E425  C23112  0.516681  0.546948  0.090335
# 74684  E425  C16280  0.512622  0.514259  0.089625
# 74685  E425  C15880  0.489320  0.054983  0.085551
# 74686  E425  C15374  0.471698  0.000000  0.082470
# 74687  E425  C12064  0.253448  0.000000  0.044312
# 74688  E425  C02766  0.200000  0.000000  0.034967
# 74689  E425  C05650  0.189569  0.000000  0.033144
# 74690  E425  C14180  0.180400  0.119054  0.031541
# 74691  E425  C12006  0.146323  1.779251  0.025583
# 74692  E425  C12720  0.137845  0.000000  0.024100
# 74693  E425  C15699  0.110000  0.000000  0.019232
# 74694  E425  C05583  0.102656  0.212593  0.017948
# 74695  E425  C17430  0.095340  0.208505  0.016669
# 74696  E425  C12650  0.091165  0.846809  0.015939
# 74697  E425  C02374  0.085162  0.159698  0.014889
# 74698  E425  C11365  0.077962  0.159428  0.013631
# 74699  E425  C06845  0.072453  0.000000  0.012667
# 74700  E425  C15032  0.069032  0.592739  0.012069
# 74701  E425  C06996  0.056476  0.065657  0.009874
# 74702  E425  C07715  0.043509  2.513425  0.007607
# 74703  E425  C06557  0.025641  0.000000  0.004483
# 74704  E425  C12709  0.022264  0.000000  0.003893
# 74705  E425  C13932  0.021698  0.000000  0.003794
# 74706  E425  C11315  0.017708  0.210519  0.003096
# 74707  E425  C17753  0.014170  0.402208  0.002477

# %%
info.to_excel("data.xlsx")
